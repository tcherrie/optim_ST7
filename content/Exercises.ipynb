# %% [markdown]
# # Exercises
#
# _______

# %% [markdown]
# ## 1) Derivative approximation

# %% [markdown]
# We consider the following real valued functions :

# %%
def f1(x):
    return 1 + x + x**2 - x**3

def f2(x):
    return x + x**2 - x**3

def f3(x):
    return ((1 + x)**2) ** 0.5

def f4(x):
    return abs(1+x)

# %% [markdown]
# 1. Plot the graphs of the functions for $x\in [-1,1]$.

# %% [markdown]
# 2. Compute the reference derivatives.

# %% [markdown]
# 3. For $h\in [10^{-16}, 1]$ and each of the functions, plot the log-scale error of the approximated derivative at $x=0$ using the following techniques:
# - a) Forward finite difference `FD1`
# - b) Centered finite difference `FD2`
# - c) Complex step `CS`

# %%
# Derivative approximations

def FD1(f, x, h = 1e-8):
    """ Approximate first derivative with forward finite difference """
    return ...

def FD2(f, x, h = 1e-7):
    """ Approximate first derivative with centered finite difference """
    return ...

def CS(f, x, h = 1e-50):
    """ Approximate first derivative with complex step """
    return ...

# %%
# Log scale plot (f1)

import numpy as np
import matplotlib.pyplot as plt

H = np.logspace(-16,0,100)
...
plt.loglog(H, H, '--', label = "$h$")
plt.loglog(H, H**2, '--', label = "$h^2$")
plt.legend(); plt.title("Derivative error of f1 for at x=0")
plt.show()

# %%
# Log scale plot (f2)

...
plt.loglog(H, H, '--', label = "$h$")
plt.loglog(H, H**2, '--', label = "$h^2$")
plt.legend(); plt.title("Derivative error of f2 for at x=0")
plt.show()

# %%
# Log scale plot (f3)

...
plt.loglog(H, H, '--', label = "$h$")
plt.loglog(H, H**2, '--', label = "$h^2$")
plt.legend(); plt.title("Derivative error of f3 for at x=0")
plt.show()

# %%
# Log scale plot (f4)

...
plt.loglog(H, H, '--', label = "$h$")
plt.loglog(H, H**2, '--', label = "$h^2$")
plt.legend(); plt.title("Derivative error of f4 for at x=0")
plt.show()

# %%
# Log scale plot (f4)

import numpy as np
import matplotlib.pyplot as plt

...
plt.loglog(H, H, '--', label = "$h$")
plt.loglog(H, H**2, '--', label = "$h^2$")
plt.legend(); plt.title("Derivative error for at x=0")
plt.show()

# %% [markdown]
# 4. Interpret the results.

# %% [markdown]
# ______
# ## 2) Solvers
#
# We want to solve  $S(x) = Kx - f = 0$, which is linear but we don't want to use the matrix inverse. $K$ is a real matrix and is a real vector.
#
# ### a) Fixed point
#
# 1. Write $S(x) = 0$ under the form $F(x) = x$

# %% [markdown]
# 2. Try to solve the problem with a fixed point algorithm for $K = \begin{bmatrix} a, 0\\ 0, b \end{bmatrix}$ with $a,b >0$. Can it work for any $f\in \mathbb{R}^2$?

# %%
def fixedPoint(F, x0, maxit = 100, tol = 1e-8):
    """ Fixed point algorithm """
    ...

def S(x):
    return ...

def F(x)
    return ...

# %%
...

# %% [markdown]
# 3. Try to solve the problem with a fixed point for $K = \begin{bmatrix} a, 0\\ 0, b \end{bmatrix}$ with $a>0$ and $b<0$.

# %%
...

# %% [markdown]
# 4. Interpretation?

# %% [markdown]
# 5. Would Newton method, which is a special kind of fixed point, work on this problem?

# %%
def simpleNewton(F, x0, maxit = 100, tol = 1e-8):
    """ Simple Newton algorithm """
    ...

# %% [markdown]
# ### b) Newton
#
# 1. Plot the graph of the function $f_4 : x \mapsto (x-1)^3 - \pi$

# %%
def f4(x):
    return (x-1)**3 - np.pi

...

# %% [markdown]
# 2. Try to find the root of $f_4$ with the function `simpleNewton`. What kind of problems can we encounter?

# %%
...

# %% [markdown]
# 3. Implement a linesearch to avoid this issue and check the convergence speed.

# %%
def lineSearch_newton(F, x0, maxit = 100, tol = 1e-8, ...):
    """ Simple Newton algorithm """
    ...

# %% [markdown]
# 4. What happens to the convergence speed when we want to solve $f_5 : x \mapsto (x-1)^3 $?
